# %%
using TimeSeries
using Quandl

data = quandl("YAHOO/AAPL")["Adjusted Close"]
# Out:
# 100x1 TimeSeries.TimeArray{Float64,1,Date,Array{Float64,1}} 2015-08-28 to 2016-01-21
#
#              Adjusted Close
# 2015-08-28 | 112.8071
# 2015-08-31 | 112.2794
# 2015-09-01 | 107.2609
# 2015-09-02 | 111.8612
# ⋮
# 2016-01-15 | 97.13
# 2016-01-19 | 96.66
# 2016-01-20 | 96.79
# 2016-01-21 | 96.3

# %%
using Gadfly

# %%
p = plot(x = randn(3000), Geom.histogram(bincount = 100))
# Out:
# Plot(...)

# %%
data
# Out:
# 100x1 TimeSeries.TimeArray{Float64,1,Date,Array{Float64,1}} 2015-08-28 to 2016-01-21
#
#              Adjusted Close
# 2015-08-28 | 112.8071
# 2015-08-31 | 112.2794
# 2015-09-01 | 107.2609
# 2015-09-02 | 111.8612
# ⋮
# 2016-01-15 | 97.13
# 2016-01-19 | 96.66
# 2016-01-20 | 96.79
# 2016-01-21 | 96.3

# %%
using PyPlot

# %%
ts_length = 100
epsilon_values = randn(ts_length)
plot(epsilon_values, "b-")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x324d195d0>)
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x324bbd9d0>

# %%
using Distributions

# %%
function plot_histogram(distribution, n)
    epsilon_values = rand(distribution, n)
    PyPlot.plt.hist(epsilon_values)
end
# Out:
# plot_histogram (generic function with 1 method)

# %%
lp = Laplace()
# Out:
# Distributions.Laplace(μ=0.0, θ=1.0)

# %%
plot_histogram(lp, 500)
# Out:
# LoadError: type PyObject has no field hist
# while loading In[8], in expression starting on line 1
#
#  in plot_histogram at In[6]:3

# %%
hist(lp)
# Out:
# LoadError: MethodError: `hist` has no method matching hist(::Distributions.Laplace)
# while loading In[9], in expression starting on line 1

# %%
hist(epsilon_values)
# Out:
# (-3.0:1.0:3.0,[2,11,37,36,11,3])
