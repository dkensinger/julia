# %%
using TimeSeries
using Quandl

data = quandl("YAHOO/AAPL")["Adjusted Close"]
# Out:
# INFO: Recompiling stale cache file /Users/davekensinger/.julia/lib/v0.4/TimeSeries.ji for module TimeSeries.
# INFO: Recompiling stale cache file /Users/davekensinger/.julia/lib/v0.4/Quandl.ji for module Quandl.
# INFO: Recompiling stale cache file /Users/davekensinger/.julia/lib/v0.4/DataFrames.ji for module DataFrames.
# INFO: Recompiling stale cache file /Users/davekensinger/.julia/lib/v0.4/Reexport.ji for module Reexport.
# INFO: Recompiling stale cache file /Users/davekensinger/.julia/lib/v0.4/StatsBase.ji for module StatsBase.
# INFO: Recompiling stale cache file /Users/davekensinger/.julia/lib/v0.4/ArrayViews.ji for module ArrayViews.
# INFO: Recompiling stale cache file /Users/davekensinger/.julia/lib/v0.4/StatsFuns.ji for module StatsFuns.
# INFO: Recompiling stale cache file /Users/davekensinger/.julia/lib/v0.4/DataArrays.ji for module DataArrays.
# INFO: Recompiling stale cache file /Users/davekensinger/.julia/lib/v0.4/GZip.ji for module GZip.
# INFO: Recompiling stale cache file /Users/davekensinger/.julia/lib/v0.4/SortingAlgorithms.ji for module SortingAlgorithms.
# INFO: Recompiling stale cache file /Users/davekensinger/.julia/lib/v0.4/Docile.ji for module Docile.
# INFO: Recompiling stale cache file /Users/davekensinger/.julia/lib/v0.4/Requests.ji for module Requests.
# INFO: Recompiling stale cache file /Users/davekensinger/.julia/lib/v0.4/HttpCommon.ji for module HttpCommon.
# INFO: Recompiling stale cache file /Users/davekensinger/.julia/lib/v0.4/HttpParser.ji for module HttpParser.
# INFO: Recompiling stale cache file /Users/davekensinger/.julia/lib/v0.4/MbedTLS.ji for module MbedTLS.
# INFO: Recompiling stale cache file /Users/davekensinger/.julia/lib/v0.4/Codecs.ji for module Codecs.
# INFO: Recompiling stale cache file /Users/davekensinger/.julia/lib/v0.4/Libz.ji for module Libz.
# INFO: Recompiling stale cache file /Users/davekensinger/.julia/lib/v0.4/BufferedStreams.ji for module BufferedStreams.
# 100x1 TimeSeries.TimeArray{Float64,1,Date,Array{Float64,1}} 2015-08-24 to 2016-01-14
#
#              Adjusted Close
# 2015-08-24 | 102.6805
# 2015-08-25 | 103.2978
# 2015-08-26 | 109.2225
# 2015-08-27 | 112.4387
# ⋮
# 2016-01-11 | 98.53
# 2016-01-12 | 99.96
# 2016-01-13 | 97.39
# 2016-01-14 | 99.52

# %%
using Gadfly

# %%
p = plot(x = randn(3000), Geom.histogram(bincount = 100))
# Out:
# Plot(...)

# %%
data
# Out:
# 100x1 TimeSeries.TimeArray{Float64,1,Date,Array{Float64,1}} 2015-08-24 to 2016-01-14
#
#              Adjusted Close
# 2015-08-24 | 102.6805
# 2015-08-25 | 103.2978
# 2015-08-26 | 109.2225
# 2015-08-27 | 112.4387
# ⋮
# 2016-01-11 | 98.53
# 2016-01-12 | 99.96
# 2016-01-13 | 97.39
# 2016-01-14 | 99.52

# %%
using PyPlot
# Out:
# INFO: Recompiling stale cache file /Users/davekensinger/.julia/lib/v0.4/PyPlot.ji for module PyPlot.
# INFO: Recompiling stale cache file /Users/davekensinger/.julia/lib/v0.4/PyCall.ji for module PyCall.
# INFO: Recompiling stale cache file /Users/davekensinger/.julia/lib/v0.4/Colors.ji for module Colors.
# INFO: Recompiling stale cache file /Users/davekensinger/.julia/lib/v0.4/FixedPointNumbers.ji for module FixedPointNumbers.
# INFO: Recompiling stale cache file /Users/davekensinger/.julia/lib/v0.4/ColorTypes.ji for module ColorTypes.
# INFO: Recompiling stale cache file /Users/davekensinger/.julia/lib/v0.4/LaTeXStrings.ji for module LaTeXStrings.

# %%
ts_length = 100
epsilon_values = randn(ts_length)
plot(epsilon_values, "b-")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x31e4af5d0>)
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x31e3939d0>

# %%
using Distributions
# Out:
# INFO: Recompiling stale cache file /Users/davekensinger/.julia/lib/v0.4/Distributions.ji for module Distributions.
# INFO: Recompiling stale cache file /Users/davekensinger/.julia/lib/v0.4/PDMats.ji for module PDMats.

# %%
function plot_histogram(distribution, n)
    epsilon_values = rand(distribution, n)
    PyPlot.plt.hist(epsilon_values)
end
# Out:
# plot_histogram (generic function with 1 method)

# %%
lp = Laplace()
# Out:
# Distributions.Laplace(μ=0.0, θ=1.0)

# %%
plot_histogram(lp, 500)
# Out:
# LoadError: type PyObject has no field hist
# while loading In[8], in expression starting on line 1
#
#  in plot_histogram at In[6]:3

# %%
hist(lp)
# Out:
# LoadError: MethodError: `hist` has no method matching hist(::Distributions.Laplace)
# while loading In[9], in expression starting on line 1

# %%
hist(epsilon_values)
# Out:
# (-3.0:1.0:2.0,[3,11,35,39,12])
